# %% [markdown]
# ## 1. UNDERSTANDING THE GIVEN TASK
# #### Task Given by instructor Krish Naik
# * Solve in ipynb:
# 1. Import the dataset.
# https://archive.ics.uci.edu/ml/datasets/Algerian+Forest+Fires+Dataset++#
# 2. Do proper EDA(analysis) of your dataset and create a report
# 3. Then perform necessary preprocessing steps

# %% [markdown]
# ## 2. DATA COLLECTION AND UNDERSTANDING
#
# * I used a dataset on **Algerian Forest Fires** from UCI. The dataset contains a culmination of forest fire observations and data in two regions of Algeria: the Bejaia region and the Sidi Bel-Abbes region. The timeline of this dataset is from **June 2012 to September 2012**. In this project, we focused on whether certain weather features could predict forest fires in these regions using few Classification algorithms.
#
#
# * As per the Task given i choose regression problem to predict fire weather index

# %% [markdown]
# ## 3. DATA EXPLORATION
#
#
# * In this step, we will apply Exploratory Data Analysis (EDA) to extract insights from the data set to know which features have contributed more in predicting Forest fire by performing Data Analysis using Pandas and Data visualization using Matplotlib & Seaborn. It is always a good practice to understand the data first and try to gather as many insights from it.
#
#
# Below are tasks to be performed in EDA:
#
# **1. Importing Libraries**
#
#
# **2. Data Cleaning for EDA Report**
#
# **3. Exploratory Data Analysis (EDA) on all Features**

# %% [markdown]
# ### 1.Bejaia Region (located in the northeast of Algeria )

# %%
import pandas as pd

# %%
df=pd.read_excel('Bejaia region.xlsx')

# %%
df
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7  3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4  4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6  1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8  3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 117   26      9  2012           31   54   11    0.0  82.0  6.0  16.3  2.5
# 118   27      9  2012           31   66   11    0.0  85.7  8.3  24.9  4.0
# 119   28      9  2012           32   47   14    0.7  77.5  7.1   8.8  1.8
# 120   29      9  2012           26   80   16    1.8  47.4  2.9   7.7  0.3
# 121   30      9  2012           25   78   14    1.4  45.0  1.9   7.5  0.2
#
#      BUI  FWI    Classes
# 0    3.4  0.5  not fire
# 1    3.9  0.4  not fire
# ...

# %% [markdown]
# ### Attribute Information:
#
# - Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012)
# - Weather data observations
# - Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# - RH : Relative Humidity in %: 21 to 90
# - Ws :Wind speed in km/h: 6 to 29
# - Rain: total day in mm: 0 to 16.8
# ### FWI Components
# - Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# - Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# - Drought Code (DC) index from the FWI system: 7 to 220.4
# - Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# - Buildup Index (BUI) index from the FWI system: 1.1 to 68
# - Fire Weather Index (FWI) Index: 0 to 31.1
# - Classes: two classes, namely â€œFireâ€ and â€œnot Fireâ€

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  122.000000  122.000000   122.0   122.000000  122.000000  122.000000
# mean    15.754098    7.500000  2012.0    31.180328   67.975410   16.000000
# std      8.843274    1.115259     0.0     3.320401   11.154411    2.848807
# min      1.000000    6.000000  2012.0    22.000000   45.000000   11.000000
# 25%      8.000000    7.000000  2012.0    29.000000   60.000000   14.000000
# 50%     16.000000    7.500000  2012.0    31.000000   68.000000   16.000000
# 75%     23.000000    8.000000  2012.0    34.000000   77.750000   18.000000
# max     31.000000    9.000000  2012.0    37.000000   89.000000   26.000000
#
#             Rain         FFMC         DMC          DC         ISI         BUI  \
# count  122.000000  122.000000  122.000000  122.000000  122.000000  122.000000
# mean     0.842623   74.672951   12.314754   53.160656    3.655738   15.426230
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          122 non-null    int64
#  1   month        122 non-null    int64
#  2   year         122 non-null    int64
#  3   Temperature  122 non-null    int64
#  4    RH          122 non-null    int64
#  5    Ws          122 non-null    int64
#  6   Rain         122 non-null    float64
#  7   FFMC         122 non-null    float64
#  8   DMC          122 non-null    float64
#  9   DC           122 non-null    float64
#  10  ISI          122 non-null    float64
#  11  BUI          122 non-null    float64
#  12  FWI          122 non-null    float64
#  13  Classes      122 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 13.5+ KB

# %%
df.dtypes
# Out:
# day              int64
# month            int64
# year             int64
# Temperature      int64
#  RH              int64
#  Ws              int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes         object
# dtype: object

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
df['Classes  '].value_counts()
# Out:
# not fire       60
# fire           53
# fire            4
# fire            2
# not fire        2
# not fire        1
# Name: Classes  , dtype: int64

# %%
st1='not fire'
st2='fire'
lst=df['Classes  '].to_list()
for i in range(len(lst)):
    if st1 in lst[i]:
        lst[i]=st1
    elif st2 in lst[i]:
        lst[i]=st2

# %%
df['classes']=lst

# %%
df
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7  3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4  4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6  1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8  3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 117   26      9  2012           31   54   11    0.0  82.0  6.0  16.3  2.5
# 118   27      9  2012           31   66   11    0.0  85.7  8.3  24.9  4.0
# 119   28      9  2012           32   47   14    0.7  77.5  7.1   8.8  1.8
# 120   29      9  2012           26   80   16    1.8  47.4  2.9   7.7  0.3
# 121   30      9  2012           25   78   14    1.4  45.0  1.9   7.5  0.2
#
#      BUI  FWI    Classes     classes
# 0    3.4  0.5  not fire     not fire
# ...

# %%
df['classes'].value_counts()
# Out:
# not fire    63
# fire        59
# Name: classes, dtype: int64

# %%
df.drop(['Classes  '], axis=1,inplace=True)

# %%
df
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7  3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4  4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6  1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8  3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 117   26      9  2012           31   54   11    0.0  82.0  6.0  16.3  2.5
# 118   27      9  2012           31   66   11    0.0  85.7  8.3  24.9  4.0
# 119   28      9  2012           32   47   14    0.7  77.5  7.1   8.8  1.8
# 120   29      9  2012           26   80   16    1.8  47.4  2.9   7.7  0.3
# 121   30      9  2012           25   78   14    1.4  45.0  1.9   7.5  0.2
#
#      BUI  FWI   classes
# 0    3.4  0.5  not fire
# 1    3.9  0.4  not fire
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(df['classes'].value_counts())
# Out:
# <AxesSubplot: >

# %%
sns.catplot(x="classes", kind="count", data=df,height=3,aspect=1)

# %%
df.corr('spearman')
# Out:
# /tmp/ipykernel_77/1436705525.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr('spearman')
#                   day     month  year  Temperature        RH        Ws  \
# day          1.000000  0.000000   NaN     0.164575 -0.189278  0.091539
# month        0.000000  1.000000   NaN     0.008319 -0.086637 -0.010369
# year              NaN       NaN   NaN          NaN       NaN       NaN
# Temperature  0.164575  0.008319   NaN     1.000000 -0.668793 -0.166972
#  RH         -0.189278 -0.086637   NaN    -0.668793  1.000000  0.229247
#  Ws          0.091539 -0.010369   NaN    -0.166972  0.229247  1.000000
# Rain        -0.199772  0.137666   NaN    -0.472680  0.371293  0.177250
# FFMC         0.347058 -0.014140   NaN     0.712207 -0.655197 -0.141171
# ...

# %%
ax=sns.countplot(x='month' ,hue='classes', data=df)
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ### Insight
# - Fire in each month
# - June - 13
# - July - 15
# - August - 24
# - September - 7

# %%
ax=sns.countplot(x='day' ,hue=df['classes'], data=df)
plt.figure(figsize=(20,4))
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ### Insights
# - Starting of month it is safe
# -- Chances of Fire is more after mid of month

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr('spearman'),annot=True)
# Out:
# /tmp/ipykernel_77/1534109974.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr('spearman'),annot=True)
# <AxesSubplot: >

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'classes'],
#       dtype='object')

# %%
df[' RH']
# Out:
# 0      57
# 1      61
# 2      82
# 3      89
# 4      77
#        ..
# 117    54
# 118    66
# 119    47
# 120    80
# 121    78
# Name:  RH, Length: 122, dtype: int64

# %%
df[df['classes']=='fire']
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC     DC   ISI  \
# 5      6      6  2012           31   67   14    0.0  82.6   5.8   22.2   3.1
# 6      7      6  2012           33   54   13    0.0  88.2   9.9   30.5   6.4
# 7      8      6  2012           30   73   15    0.0  86.6  12.1   38.3   5.6
# 10    11      6  2012           31   65   14    0.0  84.5  12.5   54.3   4.0
# 11    12      6  2012           26   81   19    0.0  84.0  13.8   61.4   4.8
# 20    21      6  2012           30   78   14    0.0  81.0   6.3   31.6   2.6
# 22    23      6  2012           32   62   18    0.1  81.4   8.2   47.7   3.3
# 23    24      6  2012           32   66   17    0.0  85.9  11.2   55.8   5.6
# 24    25      6  2012           31   64   15    0.0  86.7  14.2   63.8   5.7
# 25    26      6  2012           31   64   18    0.0  86.8  17.8   71.8   6.7
# 26    27      6  2012           34   53   18    0.0  89.0  21.6   80.3   9.2
# ...

# %%
ax=sns.countplot(x='month' ,hue='classes', data=df[df['classes']=='fire'])
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ### Insight
# - Fire in each month
# - June - 13
# - July - 15
# - August - 24
# - September - 7

# %%
sns.pairplot(data=df[df['classes']=='fire'])

# %%
import seaborn as sns
sns.scatterplot(x=' RH',data=df)
# Out:
# <AxesSubplot: xlabel=' RH'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.xlim(0,30)
plt.ylabel('Price')
sns.boxplot(x=df['Rain '])
plt.show()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'classes'],
#       dtype='object')

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  122.000000  122.000000   122.0   122.000000  122.000000  122.000000
# mean    15.754098    7.500000  2012.0    31.180328   67.975410   16.000000
# std      8.843274    1.115259     0.0     3.320401   11.154411    2.848807
# min      1.000000    6.000000  2012.0    22.000000   45.000000   11.000000
# 25%      8.000000    7.000000  2012.0    29.000000   60.000000   14.000000
# 50%     16.000000    7.500000  2012.0    31.000000   68.000000   16.000000
# 75%     23.000000    8.000000  2012.0    34.000000   77.750000   18.000000
# max     31.000000    9.000000  2012.0    37.000000   89.000000   26.000000
#
#             Rain         FFMC         DMC          DC         ISI         BUI  \
# count  122.000000  122.000000  122.000000  122.000000  122.000000  122.000000
# mean     0.842623   74.672951   12.314754   53.160656    3.655738   15.426230
# ...

# %%
for i in df.columns:
    print(i)
# Out:
# day
# month
# year
# Temperature
#  RH
#  Ws
# Rain
# FFMC
# DMC
# DC
# ISI
# BUI
# FWI
# classes

# %%
from numpy import percentile
Q1,Q2,Q3 = percentile(df['Rain '], [25, 50, 75])
IQR=Q3-Q1
LOWER_FENCE=Q1-(1.5*IQR)
HIGHER_FENCE=Q3+(1.5*IQR)

# %%
for i in df['Rain '].to_list():
    if(i<LOWER_FENCE) or (i>HIGHER_FENCE):
        print(i)
# Out:
# 1.3
# 13.1
# 2.5
# 3.1
# 1.4
# 16.8
# 7.2
# 10.1
# 3.8
# 1.8
# 1.8
# 4.6
# 8.3
# 5.8
# 1.8
# 1.4

# %%
l=df['Rain '].to_list()
df["Rain "].str.replace(,"")
# Out:
#   Cell In[32], line 2
#     df["Rain "].str.replace(,"")
#                             ^
# SyntaxError: invalid syntax

# %%
sns.scatterplot(df['Rain '],markers=df['classes'])
# Out:
# <AxesSubplot: ylabel='Rain '>

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'classes'],
#       dtype='object')
